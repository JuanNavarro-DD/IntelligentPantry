# %%
import gym
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
env = gym.make('IntelligentPantry-v1')

# %%
episodes = 5 
for episode in range(1,episodes+1):
    state = env.reset()
    done = False
    score = 0
    
    while not done:
        #env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+= reward
    print("Episode:{} Score:{}".format(episode,score))
env.close()
# Out:
# Episode:1 Score:-103.29527667664873
# Episode:2 Score:-97.28717464004029
# Episode:3 Score:-113.70252853770218
# Episode:4 Score:-102.16442395309222
# Episode:5 Score:-103.36030515506343

# %%
env.action_space
# Out:
# Box(-1.0, 1.0, (2,), float32)

# %%
env.action_space.sample()
# Out:
# array([0.7725668, 0.3274617], dtype=float32)

# %%
env.observation_space
# Out:
# Box(-inf, inf, (11,), float64)

# %%
env.step(1)
# Out:
# (array([ 0.83478577, -0.97261645,  0.5505749 ,  0.2324161 , -0.08778584,
#          0.0257037 ,  1.87623715,  3.87752434, -0.19554875, -0.23272672,
#          0.        ]),
#  -1.2989277012743594,
#  True,
#  {'reward_dist': -0.2989277012743593,
#   'reward_ctrl': -1,
#   'TimeLimit.truncated': True})

# %%
env.spec.reward_threshold
# Out:
# -3.75

# %%
a=[1,2,3,4,5,6]
a[:-2]
# Out:
# [1, 2, 3, 4]

# %%
import numpy as np
env.np_random.uniform(low=-0.1, high=0.1, size=env.model.nq)
# Out:
# array([-0.08364105, -0.04591886,  0.19119831, -0.05196949])

# %%
env.init_qpos
# Out:
# array([ 0. ,  0. ,  0.1, -0.1])

# %% [markdown]
# # Train

# %%
log_path = os.path.join('training','Logs')

# %%
log_path
# Out:
# 'training/Logs'

# %%
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy',env,verbose=1,tensorboard_log=log_path)
# Out:
# Using cuda device

# %%
model.learn(total_timesteps = 500000)
# Out:
# 2021-11-01 19:02:18.071919: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/juan/Documents/Github/IntelligentPantry/Juan's project/PP/lib/python3.9/site-packages/mujoco_py/binaries/linux/mujoco210/bin
# 2021-11-01 19:02:18.071986: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Logging to training/Logs/PPO_5
# -----------------------------
# | time/              |      |
# |    fps             | 623  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 716          |
# |    iterations           | 2            |
# ...

# %%
 evaluate_policy(model,env,n_eval_episodes=20,render=False)
# Out:
# (-10.952795110977604, 1.381131565317606)

# %%
from stable_baselines3 import DDPG

env = gym.make("Reacher-v2")
n_actions = env.action_space.shape[-1]

# %%
model2 = DDPG('MlpPolicy',env,verbose=1,tensorboard_log=log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model2.learn(total_timesteps=500000, log_interval=10)
# Out:
# Logging to training/Logs/DDPG_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -24.8    |
# | time/              |          |
# |    episodes        | 10       |
# |    fps             | 299      |
# |    time_elapsed    | 1        |
# |    total timesteps | 500      |
# | train/             |          |
# |    actor_loss      | 0.847    |
# |    critic_loss     | 0.0119   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 350      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -19.3    |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 269      |
# |    time_elapsed    | 3        |
# |    total timesteps | 1000     |
# | train/             |          |
# |    actor_loss      | 1.44     |
# ...

# %%
 evaluate_policy(model2,env,n_eval_episodes=20,render=False)
# Out:
# (-5.774505365124059, 2.05174155786902)

# %%
from stable_baselines3 import TD3

# %%
model3 = TD3("MlpPolicy",env,verbose=1)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model3.learn(total_timesteps=500000,log_interval=10)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33.9    |
# | time/              |          |
# |    episodes        | 10       |
# |    fps             | 243      |
# |    time_elapsed    | 2        |
# |    total timesteps | 500      |
# | train/             |          |
# |    actor_loss      | 1.19     |
# |    critic_loss     | 0.0292   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 350      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -29.3    |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 216      |
# |    time_elapsed    | 4        |
# |    total timesteps | 1000     |
# | train/             |          |
# |    actor_loss      | 1.69     |
# |    critic_loss     | 0.0248   |
# ...

# %%
 evaluate_policy(model3,env,n_eval_episodes=20,render=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_23402/3576485714.py in <module>
# ----> 1 evaluate_policy(model3,env,n_eval_episodes=20,render=False)
#
# NameError: name 'model3' is not defined
